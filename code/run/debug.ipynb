# %%
from iohelper import *
from selector import *
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt
from kinematic import *
from combinator import *
from kplotter import *

# %%
# kstar_same = ak.from_parquet("/nishome/kangye/data_kangye/ppfemto/kstar/same/charm_h_*/kstar.parquet")
# kstar_mix = ak.from_parquet("/nishome/kangye/data_kangye/ppfemto/kstar/mix/charm_h_*/kstar*.parquet")
# costheta_same = ak.from_parquet("/nishome/kangye/data_kangye/ppfemto/kstar/same/charm_h_*/costheta.parquet")
# costheta_mix = ak.from_parquet("/nishome/kangye/data_kangye/ppfemto/kstar/mix/charm_h_*/costheta*.parquet")

# centers, ratio, err = get_ratio(
#     kstar_same=kstar_same ,
#     kstar_mix=kstar_mix,
#     bins=500,
#     range=(0,2000),
# )

# plot_ratio(
#     centers=centers,
#     ratio=ratio,
#     err=err, 
#     xlim=[0,100], 
#     ylim=[0,40],)

# plt.hist(np.arccos(ak.flatten(costheta_mix, axis=None).to_numpy()), bins=100, range=(0,0.05))
# plt.show()

# plt.hist(np.arccos(ak.flatten(costheta_same, axis=None).to_numpy()), bins=100, range=(0,0.02))
# plt.show()

# %%
X = ak.from_parquet("/nishome/kangye/data_kangye/ppfemto/tmp/test.parquet")
Xp = ak.from_parquet("/nishome/kangye/data_kangye/ppfemto/tmp/withPID.parquet")

# %%
allremove = cos_theta(gen_pair(remove_clone_tracks(X)))
ppremove = cos_theta(gen_pair(remove_clone_tracks(Xp)))
all = cos_theta(gen_pair(X))
pp = cos_theta(gen_pair(Xp))

# %%
plt.hist(np.arccos(ak.flatten(all, axis=None)), bins=100, range=(0, 0.01), density=True, histtype="step", label="all")
plt.hist(np.arccos(ak.flatten(allremove, axis=None)), bins=100, range=(0, 0.01), density=True, histtype="step", label="all, remove clonetrack")
plt.legend()
plt.show()

# %%
plt.hist(np.arccos(ak.flatten(pp, axis=None)), bins=100, range=(0,0.01), density=True, histtype="step", label="pp")
plt.hist(np.arccos(ak.flatten(ppremove, axis=None)), bins=100, range=(0,0.01), density=True, histtype="step", label="pp, remove clonetrack")
plt.legend()
plt.show()
