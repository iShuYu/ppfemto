# %%
from iohelper import *
from selector import *
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt

# %%
input_path = "/st0/lhcb/wangjq/raw_data/charm_h_magdown25c4/00326690_00000001_1.data_25c4.root"
tree_path = "D02kpi/DecayTree"
cfg_io_path = "/nishome/kangye/ppfemto/code/cfg/config_io.json"
cfg_select_path = "/nishome/kangye/ppfemto/code/cfg/config_select.json"

# %%
x = reduce_raw(
    input_path,
    tree_path,
    cfg_select_path,
    cfg_io_path,
    output_path="/nishome/kangye/data_kangye/ppfemto/reduced/00326690_00000001_1.data_25c4.parquet",
)

# %%
x
